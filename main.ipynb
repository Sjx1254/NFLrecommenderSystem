# %%
#where we will execute all the commands to get all the data files
import import_ipynb
from RosterSplits import RosterAndSplits

# %%
roster_2004 = RosterAndSplits("clt", "2004", "test2")

# %%
print("DEBUG rows_and_columns signature:", roster_2004.rows_and_columns.__code__.co_varnames)
# Out:
# DEBUG rows_and_columns signature: ('self', 'all_rows', 'all_cols', 'text', 'table_ids', 'hidden_tables', 'id', 'cur', 'cur_rows', 'columnT', 'cols', 'title', 'header', 'table')

# %%
roster_2004.evaluate()
