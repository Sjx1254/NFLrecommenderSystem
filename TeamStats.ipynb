# %%
import requests
from bs4 import BeautifulSoup, Commentimport pandas as pd
import os
import import_ipynb
from RosterSplits import RosterAndSplits

# %%
class TeamStat:
    def __init__(self, team, year, output_folder="output"):
        self.team = team
        self.year = year
        self.output_folder = output_folder
        self.urls = []
        self.all_rows = dict()
        self.all_cols = dict()
